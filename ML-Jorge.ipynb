# %% [markdown]
# # About this file
#
# https://www.kaggle.com/datasets/rabieelkharoua/chronic-kidney-disease-dataset-analysis?resource=download
#
# - PatientID: A unique identifier assigned to each patient (1 to 1,659).
# - Age: The age of the patients ranges from 20 to 90 years.
# - Gender: Gender of the patients, where 0 represents Male and 1 represents Female.
# - Ethnicity: The ethnicity of the patients, coded as follows:
# 0: Caucasian
# 1: African American
# 2: Asian
# 3: Other
# - SocioeconomicStatus: The socioeconomic status of the patients
# - EducationLevel: The education level of the patients, coded as follows:
# 0: None
# 1: High School
# 2: Bachelor's
# 3: Higher
# - BMI: Body Mass Index of the patients, ranging from 15 to 40.
# - Smoking: Smoking status, where 0 indicates No and 1 indicates Yes.
# - AlcoholConsumption: Weekly alcohol consumption in units, ranging from 0 to 20.
# - PhysicalActivity: Weekly physical activity in hours, ranging from 0 to 10.
# - DietQuality: Diet quality score, ranging from 0 to 10.
# - SleepQuality: Sleep quality score, ranging from 4 to 10.
# - FamilyHistoryKidneyDisease: Family history of kidney disease, where 0 indicates No and 1 indicates Yes.
# - FamilyHistoryHypertension: Family history of hypertension, where 0 indicates No and 1 indicates Yes.
# - FamilyHistoryDiabetes: Family history of diabetes, where 0 indicates No and 1 indicates Yes.
# - PreviousAcuteKidneyInjury: History of previous acute kidney injury, where 0 indicates No and 1 indicates Yes.
# - UrinaryTractInfections: History of urinary tract infections, where 0 indicates No and 1 indicates Yes.
# - SystolicBP: Systolic blood pressure, ranging from 90 to 180 mmHg.
# - DiastolicBP: Diastolic blood pressure, ranging from 60 to 120 mmHg.
# - FastingBloodSugar: Fasting blood sugar levels, ranging from 70 to 200 mg/dL.
# - HbA1c: Hemoglobin A1c levels, ranging from 4.0% to 10.0%.
# - SerumCreatinine: Serum creatinine levels, ranging from 0.5 to 5.0 mg/dL.
# - BUNLevels: Blood Urea Nitrogen levels, ranging from 5 to 50 mg/dL.
# - GFR: Glomerular Filtration Rate, ranging from 15 to 120 mL/min/1.73 m².
# - ProteinInUrine: Protein levels in urine, ranging from 0 to 5 g/day.
# - ACR: Albumin-to-Creatinine Ratio, ranging from 0 to 300 mg/g.
# - SerumElectrolytesSodium: Serum sodium levels, ranging from 135 to 145 mEq/L.
# - SerumElectrolytesPotassium: Serum potassium levels, ranging from 3.5 to 5.5 mEq/L.
# - SerumElectrolytesCalcium: Serum calcium levels, ranging from 8.5 to 10.5 mg/dL.
# - SerumElectrolytesPhosphorus: Serum phosphorus levels, ranging from 2.5 to 4.5 mg/dL.
# - HemoglobinLevels: Hemoglobin levels, ranging from 10 to 18 g/dL.
# - CholesterolTotal: Total cholesterol levels, ranging from 150 to 300 mg/dL.
# - CholesterolLDL: Low-density lipoprotein cholesterol levels, ranging from 50 to 200 mg/dL.
# - CholesterolHDL: High-density lipoprotein cholesterol levels, ranging from 20 to 100 mg/dL.
# - CholesterolTriglycerides: Triglycerides levels, ranging from 50 to 400 mg/dL.
# - ACEInhibitors: Use of ACE inhibitors, where 0 indicates No and 1 indicates Yes.
# - Diuretics: Use of diuretics, where 0 indicates No and 1 indicates Yes.
# - NSAIDsUse: Frequency of NSAIDs use, ranging from 0 to 10 times per week.
# - Statins: Use of statins, where 0 indicates No and 1 indicates Yes.
# - AntidiabeticMedications: Use of antidiabetic medications, where 0 indicates No and 1 indicates Yes.
# - Edema: Presence of edema, where 0 indicates No and 1 indicates Yes.
# - FatigueLevels: Fatigue levels, ranging from 0 to 10.
# - NauseaVomiting: Frequency of nausea and vomiting, ranging from 0 to 7 times per week.
# - MuscleCramps: Frequency of muscle cramps, ranging from 0 to 7 times per week.
# - Itching: Itching severity, ranging from 0 to 10.
# - QualityOfLifeScore: Quality of life score, ranging from 0 to 100.
# - HeavyMetalsExposure: Exposure to heavy metals, where 0 indicates No and 1 indicates Yes.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb

# %%
df = pd.read_csv('Chronic_Kidney_Dsease_data.csv')

# %%
df.shape
# Out:
# (1659, 54)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0          1   71       0          0                    0               2
# 1          2   34       0          0                    1               3
# 2          3   80       1          1                    0               1
# 3          4   40       0          2                    0               1
# 4          5   43       0          1                    1               2
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  DietQuality  \
# 0  31.069414        1            5.128112          1.676220     0.240386
# 1  29.692119        1           18.609552          8.377574     6.503233
# 2  37.394822        1           11.882429          9.607401     2.104828
# 3  31.329680        0           16.020165          0.408871     6.964422
# 4  23.726311        0            7.944146          0.780319     3.097796
#
#    SleepQuality  FamilyHistoryKidneyDisease  FamilyHistoryHypertension  \
# ...

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus',
#        'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryKidneyDisease', 'FamilyHistoryHypertension',
#        'FamilyHistoryDiabetes', 'PreviousAcuteKidneyInjury',
#        'UrinaryTractInfections', 'SystolicBP', 'DiastolicBP',
#        'FastingBloodSugar', 'HbA1c', 'SerumCreatinine', 'BUNLevels', 'GFR',
#        'ProteinInUrine', 'ACR', 'SerumElectrolytesSodium',
#        'SerumElectrolytesPotassium', 'SerumElectrolytesCalcium',
#        'SerumElectrolytesPhosphorus', 'HemoglobinLevels', 'CholesterolTotal',
#        'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides',
#        'ACEInhibitors', 'Diuretics', 'NSAIDsUse', 'Statins',
#        'AntidiabeticMedications', 'Edema', 'FatigueLevels', 'NauseaVomiting',
#        'MuscleCramps', 'Itching', 'QualityOfLifeScore', 'HeavyMetalsExposure',
# ...

# %%
df['Diagnosis'].value_counts(normalize=True)
# Out:
# Diagnosis
# 1    0.918626
# 0    0.081374
# Name: proportion, dtype: float64

# %%
df[df['Diagnosis']==0]
# Out:
#       PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 7             8   72       1          0                    1               3
# 14           15   40       0          2                    0               3
# 35           36   37       0          0                    1               2
# 49           50   69       1          3                    1               0
# 66           67   72       0          1                    2               3
# ...         ...  ...     ...        ...                  ...             ...
# 1649       1650   89       0          0                    1               2
# 1651       1652   42       1          1                    1               3
# 1654       1655   90       0          0                    1               2
# 1655       1656   34       0          0                    2               1
# 1656       1657   84       0          0                    2               3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1659 entries, 0 to 1658
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PatientID                      1659 non-null   int64
#  1   Age                            1659 non-null   int64
#  2   Gender                         1659 non-null   int64
#  3   Ethnicity                      1659 non-null   int64
#  4   SocioeconomicStatus            1659 non-null   int64
#  5   EducationLevel                 1659 non-null   int64
#  6   BMI                            1659 non-null   float64
#  7   Smoking                        1659 non-null   int64
#  8   AlcoholConsumption             1659 non-null   float64
#  9   PhysicalActivity               1659 non-null   float64
#  10  DietQuality                    1659 non-null   float64
#  11  SleepQuality                   1659 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# PatientID                        0
# Age                              0
# Gender                           0
# Ethnicity                        0
# SocioeconomicStatus              0
# EducationLevel                   0
# BMI                              0
# Smoking                          0
# AlcoholConsumption               0
# PhysicalActivity                 0
# DietQuality                      0
# SleepQuality                     0
# FamilyHistoryKidneyDisease       0
# FamilyHistoryHypertension        0
# FamilyHistoryDiabetes            0
# PreviousAcuteKidneyInjury        0
# UrinaryTractInfections           0
# SystolicBP                       0
# DiastolicBP                      0
# FastingBloodSugar                0
# HbA1c                            0
# SerumCreatinine                  0
# BUNLevels                        0
# GFR                              0
# ProteinInUrine                   0
# ACR                              0
# SerumElectrolytesSodium          0
# ...

# %% [markdown]
# Tras hacer la comprobaciones eliminamos las columnas que no nos interesan como PacientID y DoctorInCharge

# %%
df.drop(columns=['PatientID', 'DoctorInCharge'], inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel        BMI  \
# 0   71       0          0                    0               2  31.069414
# 1   34       0          0                    1               3  29.692119
# 2   80       1          1                    0               1  37.394822
# 3   40       0          2                    0               1  31.329680
# 4   43       0          1                    1               2  23.726311
#
#    Smoking  AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0        1            5.128112          1.676220     0.240386      4.076434
# 1        1           18.609552          8.377574     6.503233      7.652813
# 2        1           11.882429          9.607401     2.104828      4.392786
# 3        0           16.020165          0.408871     6.964422      6.282274
# 4        0            7.944146          0.780319     3.097796      4.021639
#
#    FamilyHistoryKidneyDisease  FamilyHistoryHypertension  \
# ...

# %% [markdown]
# Revisamos que variables van a necesitar que las dividamos empleando metodos como get dummies o one hot encoder

# %%
df.nunique()
# Out:
# Age                                71
# Gender                              2
# Ethnicity                           4
# SocioeconomicStatus                 3
# EducationLevel                      4
# BMI                              1659
# Smoking                             2
# AlcoholConsumption               1659
# PhysicalActivity                 1659
# DietQuality                      1659
# SleepQuality                     1659
# FamilyHistoryKidneyDisease          2
# FamilyHistoryHypertension           2
# FamilyHistoryDiabetes               2
# PreviousAcuteKidneyInjury           2
# UrinaryTractInfections              2
# SystolicBP                         90
# DiastolicBP                        60
# FastingBloodSugar                1659
# HbA1c                            1659
# SerumCreatinine                  1659
# BUNLevels                        1659
# GFR                              1659
# ProteinInUrine                   1659
# ACR                              1659
# ...

# %%
# realizamos get_dummies con las columnas Ethnicity, SocioeconomicStatus y EducationLevel.
# Con las variables de dos valores no hace falta qque se cambien puesto que ya están como queremos, con unos y ceros.

df = pd.get_dummies(df, columns=['Ethnicity', 'SocioeconomicStatus', 'EducationLevel'])

# %%
df.head()
# Out:
#    Age  Gender        BMI  Smoking  AlcoholConsumption  PhysicalActivity  \
# 0   71       0  31.069414        1            5.128112          1.676220
# 1   34       0  29.692119        1           18.609552          8.377574
# 2   80       1  37.394822        1           11.882429          9.607401
# 3   40       0  31.329680        0           16.020165          0.408871
# 4   43       0  23.726311        0            7.944146          0.780319
#
#    DietQuality  SleepQuality  FamilyHistoryKidneyDisease  \
# 0     0.240386      4.076434                           0
# 1     6.503233      7.652813                           1
# 2     2.104828      4.392786                           0
# 3     6.964422      6.282274                           0
# 4     3.097796      4.021639                           0
#
#    FamilyHistoryHypertension  FamilyHistoryDiabetes  \
# 0                          0                      0
# 1                          1                      0
# ...

# %%
df.corr()
# Out:
#                                     Age    Gender       BMI   Smoking  \
# Age                            1.000000 -0.037765 -0.033202  0.020215
# Gender                        -0.037765  1.000000 -0.023381  0.004054
# BMI                           -0.033202 -0.023381  1.000000 -0.000968
# Smoking                        0.020215  0.004054 -0.000968  1.000000
# AlcoholConsumption            -0.006030 -0.020473 -0.067239  0.032707
# PhysicalActivity               0.003485  0.014840  0.003528  0.006153
# DietQuality                    0.004062  0.011517  0.014539 -0.006386
# SleepQuality                  -0.005151 -0.004312  0.011668  0.013974
# FamilyHistoryKidneyDisease     0.014984  0.032584  0.026117 -0.024922
# FamilyHistoryHypertension     -0.008672 -0.007058 -0.001755  0.001519
# FamilyHistoryDiabetes          0.001114  0.019137 -0.010746 -0.045710
# PreviousAcuteKidneyInjury      0.028253  0.038519 -0.018380  0.003166
# ...

# %%
df.corr()['Diagnosis'].sort_values(ascending=False)
# Out:
# Diagnosis                        1.000000
# SerumCreatinine                  0.201125
# Itching                          0.100652
# FastingBloodSugar                0.095694
# MuscleCramps                     0.094811
# BUNLevels                        0.093097
# ProteinInUrine                   0.090014
# SystolicBP                       0.083528
# HbA1c                            0.059999
# BMI                              0.055222
# FamilyHistoryKidneyDisease       0.050935
# Edema                            0.050857
# CholesterolHDL                   0.044342
# EducationLevel_1                 0.044048
# HemoglobinLevels                 0.044001
# Gender                           0.042239
# QualityOfLifeScore               0.040657
# DiastolicBP                      0.036383
# UrinaryTractInfections           0.034617
# SerumElectrolytesSodium          0.032372
# Diuretics                        0.028236
# Smoking                          0.026875
# ...

# %%
df_2 = df.corr()['Diagnosis']

# %%
df_2 = df_2.reset_index()

# %%
df_2 = df_2[df_2["index"]!="Diagnosis"]

# %%
df_2['Diagnosis'].sort_values(ascending=False)
# Out:
# 17    0.201125
# 40    0.100652
# 15    0.095694
# 39    0.094811
# 18    0.093097
# 20    0.090014
# 13    0.083528
# 16    0.059999
# 2     0.055222
# 8     0.050935
# 36    0.050857
# 29    0.044342
# 57    0.044048
# 26    0.044001
# 1     0.042239
# 41    0.040657
# 14    0.036383
# 12    0.034617
# 22    0.032372
# 32    0.028236
# 3     0.026875
# 54    0.024986
# 23    0.023686
# 9     0.022520
# 7     0.021277
# 52    0.016211
# 53    0.015374
# 10    0.013852
# 45    0.012373
# 42    0.010108
# 33    0.006987
# 24    0.006636
# 58    0.006105
# 47    0.005186
# 31    0.004221
# 46    0.001532
# 49    0.001158
# 0     0.000919
# 21   -0.001549
# 37   -0.002884
# 11   -0.005451
# 51   -0.006050
# 4    -0.006245
# 28   -0.006809
# 34   -0.007134
# 30   -0.008489
# 50   -0.008657
# 56   -0.009588
# 25   -0.011338
# 35   -0.014582
# 43   -0.015118
# 44   -0.018790
# 38   -0.020670
# 5    -0.021550
# 27   -0.041897
# 55   -0.042624
# 6    -0.044503
# 59   -0.050009
# ...

# %%
df_2["corr_abs"] = abs(df_2["Diagnosis"])

# %%
# observamos cual es la variable con mayor correlación que hay en el dataset con el diagnostico
df_2[df_2['corr_abs']==df_2['corr_abs'].max()]
# Out:
#               index  Diagnosis  corr_abs
# 17  SerumCreatinine   0.201125  0.201125

# %% [markdown]
# ### Se realizarán 3 pruebas distintas de limpieza de las variables del data set, así comprobaremos cual es mejor.
#
# 1 - Sin eliminar variables.
#
# 2 - Eliminando las variables que estén por debajo de la media de la correlación
#
# 3 - Eliminando las variables que estén por debajo de la media de Plotting feature importance

# %%
# Se calcula la media de las correlaciones
# se eliminan

# %%
# Creación del primer datasets

df_org = df

# %%
corr = df.corr()['Diagnosis']
corr_mean = df.corr()['Diagnosis'].mean()
corr_col = [col for col in df.columns if abs(corr[col])> corr_mean]
df[corr_col]
# Out:
#       Gender        BMI  DietQuality  FamilyHistoryKidneyDisease  \
# 0          0  31.069414     0.240386                           0
# 1          0  29.692119     6.503233                           1
# 2          1  37.394822     2.104828                           0
# 3          0  31.329680     6.964422                           0
# 4          0  23.726311     3.097796                           0
# ...      ...        ...          ...                         ...
# 1654       0  39.677059     8.602873                           0
# 1655       0  28.922015     9.836919                           0
# 1656       0  21.951219     5.038194                           0
# 1657       0  24.964149     4.557577                           0
# 1658       1  19.253258     0.757396                           1
#
#       UrinaryTractInfections  SystolicBP  DiastolicBP  FastingBloodSugar  \
# 0                          0         113           83          72.510788
# ...

# %%
# Creación del dataset basado en la media de la correlación

corr = df.corr()['Diagnosis']
corr_mean = df.corr()['Diagnosis'].mean()
corr_col = [x for x in df.columns if abs(corr[x])> corr_mean]
df[corr_col]

df_corr = df[corr_col]
df_corr
# Out:
#       Gender        BMI  DietQuality  FamilyHistoryKidneyDisease  \
# 0          0  31.069414     0.240386                           0
# 1          0  29.692119     6.503233                           1
# 2          1  37.394822     2.104828                           0
# 3          0  31.329680     6.964422                           0
# 4          0  23.726311     3.097796                           0
# ...      ...        ...          ...                         ...
# 1654       0  39.677059     8.602873                           0
# 1655       0  28.922015     9.836919                           0
# 1656       0  21.951219     5.038194                           0
# 1657       0  24.964149     4.557577                           0
# 1658       1  19.253258     0.757396                           1
#
#       UrinaryTractInfections  SystolicBP  DiastolicBP  FastingBloodSugar  \
# 0                          0         113           83          72.510788
# ...

# %%
# Creación del dataset basado en el Plotting feature importance

X = df.drop(columns=['Diagnosis'])
y = df['Diagnosis']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=1453)

xgb_cls = xgb.XGBClassifier(random_state = 1453)

# Los parametros todavia no están definidos
xgb_cls.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': None,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': 1453,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
# ...

# %%
# Comprobamos que el split se ha hecho correctamente

print(y_test.mean())
print(y_train.mean())
print(df['Diagnosis'].mean())

# Parece bastante razonable
# Out:
# 0.9186746987951807
# 0.9186134137151469
# 0.918625678119349

# %%
# Declaramos algunos parametros

xgb_cls.set_params(n_stimators=10, max_depth= 3)
xgb_cls.fit(X_train, y_train)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:160: UserWarning: [10:07:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_stimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix

# %%
accuracy_score(y_train, xgb_cls.predict(X_train))
# Out:
# 1.0

# %%
accuracy_score(y_test, xgb_cls.predict(X_test))
# Out:
# 0.9457831325301205

# %%
recall_score(y_test, xgb_cls.predict(X_test))
# Out:
# 1.0

# %%
precision_score(y_test, xgb_cls.predict(X_test))
# Out:
# 0.9442724458204335

# %%
confusion_matrix(y_test, xgb_cls.predict(X_test))
# Out:
# array([[  9,  18],
#        [  0, 305]], dtype=int64)

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (15.0, 12)

xgb.plot_importance(xgb_cls, importance_type="gain", values_format='{v:.2f}')
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# Se sacan los valores del plot importance y hacemos la media
# Como da un diccionario, se saca un array
importance = xgb_cls.get_booster().get_score(importance_type='gain')

importances_array = np.array(list(importance.values()))


importance_mean = np.mean(importances_array)
importance_mean
# Out:
# 1.8191744257574496

# %%
# Se sacan los nombres de la variables con .keys()

importance_variables = np.array(list(importance.keys()))

# Se eliminan las variables que estén por debajo de la media
importance_variables = importance_variables[importances_array >= importance_mean]

# Se añade lo que en un futuro será nuestro target
importance_variables = np.append(importance_variables, 'Diagnosis')

variables = importance_variables
df_importance = df[variables]
df_importance
# Out:
#       PhysicalActivity  SystolicBP  DiastolicBP  FastingBloodSugar     HbA1c  \
# 0             1.676220         113           83          72.510788  9.212397
# 1             8.377574         120           67         100.848875  4.604989
# 2             9.607401         147          106         160.989441  5.432599
# 3             0.408871         117           65         188.506620  4.144466
# 4             0.780319          98           66          82.156699  4.262979
# ...                ...         ...          ...                ...       ...
# 1654          4.157954         130           89         195.433613  7.309465
# 1655          9.647525         127          103          73.606489  4.357399
# 1656          7.349964         118          102         163.084321  8.235078
# 1657          0.618614         163           87          98.794331  6.298927
# 1658          7.446314         111           89         161.181060  5.921710
#
# ...

# %%
importance_variables = np.append(importance_variables, 'Diagnosis')

# %%
importance_variables
# Out:
# array(['Age', 'Gender', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryKidneyDisease', 'FamilyHistoryHypertension',
#        'UrinaryTractInfections', 'SystolicBP', 'DiastolicBP',
#        'FastingBloodSugar', 'HbA1c', 'SerumCreatinine', 'BUNLevels',
#        'GFR', 'ProteinInUrine', 'ACR', 'SerumElectrolytesSodium',
#        'SerumElectrolytesPotassium', 'SerumElectrolytesCalcium',
#        'SerumElectrolytesPhosphorus', 'HemoglobinLevels',
#        'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'NSAIDsUse', 'Statins',
#        'AntidiabeticMedications', 'Edema', 'FatigueLevels',
#        'NauseaVomiting', 'MuscleCramps', 'Itching', 'QualityOfLifeScore',
#        'WaterQuality', 'MedicalCheckupsFrequency', 'MedicationAdherence',
#        'HealthLiteracy', 'Ethnicity_0', 'Ethnicity_1',
#        'SocioeconomicStatus_2', 'EducationLevel_3', 'Diagnosis'],
# ...

# %%
# Ya tenemos los tres data sets a emplear


df_org # el original con todas las variables
df_corr # Variables por encima de la media según la correlación
df_importance # Variables por encima de la media según el plot importance (gain)

# %% [markdown]
# ## Hora de buscar los hyperparametros que funcionen mejor con RandomizedSearchCV

# %% [markdown]
# Los hyperparametros con los que se va a trabajar son:
#
# - `n_estimators`: El número de arboles de nuestro modelo.
#
# - `max_depth`: Con esto observaremos cuanto se debe profundicar en cada árbol.
#
# - `subsample`: Escogemos una proporción o fracción de los datos usados por cada árbol.
#
# - `learning_rate`: Le restamos el peso que puedan tener los árboles para evitar el overfitting.
#
# - `alpha`: Le restamos el peso que puedan tener las hojas para evitar el overfitting.

# %% [markdown]
# 1. Modelo con todas las variables

# %%
# Declaramos X e y correspondientes al primer data frame con todas las variables
X_org = df_org.drop(columns=['Diagnosis'])
y_org = df_org['Diagnosis']

# %%
# Realizamos el split, y declaramos el XGBClassifier

X_train_org, X_test_org, y_train_org, y_test_org = train_test_split(X_org, y_org, test_size=.2, random_state=42)
xgb_cls_org = xgb.XGBClassifier(random_state = 42)

# %%
# Comprobamos el split

print(y_test_org.mean())
print(y_train_org.mean())
print(df_org['Diagnosis'].mean())
# Out:
# 0.927710843373494
# 0.9163526752072344
# 0.918625678119349

# %%
# Creamos los parametros del RandomizeSearchCV

from sklearn.model_selection import RandomizedSearchCV

rs_param_grid = {
    'n_estimators': [10, 25, 40],
    'max_depth': list((range(3,12))),
    'subsample': [0.25,0.5,0.75,1],
    'learning_rate': np.linspace(0.01,0.5, 1),
    'alpha': [0,0.001, 0.01,0.1,1]
    }

# %%
# Hacemos el RandomizedSearchCV

xgb_rs_org = RandomizedSearchCV(estimator=xgb_cls_org,param_distributions=rs_param_grid, 
                                cv=3, n_iter=500, random_state=42)

# %%
# Entrenamos nuestro modelo

xgb_rs_org.fit(X_train_org, y_train_org)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            min_child_weight=None, missing=nan,
# ...

# %%
xgb_rs_org.best_params_
# Out:
# {'subsample': 0.5,
#  'n_estimators': 10,
#  'max_depth': 4,
#  'learning_rate': 0.01,
#  'alpha': 0.01}

# %%
xgb_cls_org.set_params(n_stimators=10, max_depth= 4, subsample=0.5, learning_rate=0.01, alpha= 0.01)
xgb_cls_org.fit(X_train_org, y_train_org)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:160: UserWarning: [13:50:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_stimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(alpha=0.01, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
# ...

# %%
print(confusion_matrix(y_train_org, xgb_cls_org.predict(X_train_org)))
print(accuracy_score(y_train_org, xgb_cls_org.predict(X_train_org)))
print(recall_score(y_train_org, xgb_cls_org.predict(X_train_org)))
print(precision_score(y_train_org, xgb_cls_org.predict(X_train_org)))
# Out:
# [[   9  102]
#  [   0 1216]]
# 0.9231348907309721
# 1.0
# 0.9226100151745068

# %%
print(confusion_matrix(y_test_org, xgb_cls_org.predict(X_test_org)))
print(accuracy_score(y_test_org, xgb_cls_org.predict(X_test_org)))
print(recall_score(y_test_org, xgb_cls_org.predict(X_test_org)))
print(precision_score(y_test_org, xgb_cls_org.predict(X_test_org)))
# Out:
# [[  0  24]
#  [  0 308]]
# 0.927710843373494
# 1.0
# 0.927710843373494

# %% [markdown]
# 2. Modelo con las variables con mejor correlación

# %%
# Declaramos X e y correspondientes al primer data frame con todas las variables
X_corr = df_corr.drop(columns=['Diagnosis'])
y_corr = df_corr['Diagnosis']

# Realizamos el split, y declaramos el XGBClassifier

X_train_corr, X_test_corr, y_train_corr, y_test_corr = train_test_split(X_corr, y_corr, test_size=.2, random_state=42)
xgb_cls_corr = xgb.XGBClassifier(random_state = 42)

# Comprobamos el split

print(y_test_corr.mean())
print(y_train_corr.mean())
print(df_corr['Diagnosis'].mean())
# Out:
# 0.927710843373494
# 0.9163526752072344
# 0.918625678119349

# %%
# Hacemos el RandomizedSearchCV

xgb_rs_corr = RandomizedSearchCV(estimator=xgb_cls_corr,param_distributions=rs_param_grid, 
                                cv=3, n_iter=500, random_state=42)

# Entrenamos nuestro modelo

xgb_rs_corr.fit(X_train_corr, y_train_corr)

xgb_rs_corr.best_params_
# Out:
# {'subsample': 0.5,
#  'n_estimators': 10,
#  'max_depth': 4,
#  'learning_rate': 0.01,
#  'alpha': 0.01}

# %%
# Entrenamos el modelo con los parametros ajustados

xgb_cls_corr.set_params(n_stimators=10, max_depth= 4, subsample=0.5, learning_rate=0.01, alpha= 0.01)
xgb_cls_corr.fit(X_train_corr, y_train_corr)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:160: UserWarning: [14:01:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_stimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(alpha=0.01, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
# ...

# %%
# Resultados sobre el train

print(confusion_matrix(y_train_corr, xgb_cls_corr.predict(X_train_corr)))
print(accuracy_score(y_train_corr, xgb_cls_corr.predict(X_train_corr)))
print(recall_score(y_train_corr, xgb_cls_corr.predict(X_train_corr)))
print(precision_score(y_train_corr, xgb_cls_corr.predict(X_train_corr)))
# Out:
# [[   9  102]
#  [   0 1216]]
# 0.9231348907309721
# 1.0
# 0.9226100151745068

# %%
# Resultados sobre el test

print(confusion_matrix(y_test_corr, xgb_cls_corr.predict(X_test_corr)))
print(accuracy_score(y_test_corr, xgb_cls_corr.predict(X_test_corr)))
print(recall_score(y_test_corr, xgb_cls_corr.predict(X_test_corr)))
print(precision_score(y_test_corr, xgb_cls_corr.predict(X_test_corr)))
# Out:
# [[  1  23]
#  [  0 308]]
# 0.9307228915662651
# 1.0
# 0.9305135951661632

# %% [markdown]
# 3. Modelo con las variables con mejor plot_importance

# %%
# Declaramos X e y correspondientes al primer data frame con todas las variables
X_importance = df_importance.drop(columns=['Diagnosis'])
y_importance = df_importance['Diagnosis']

# Realizamos el split, y declaramos el XGBClassifier

X_train_importance, X_test_importance, y_train_importance, y_test_importance = train_test_split(X_importance, y_importance, test_size=.2, random_state=42)
xgb_cls_importance = xgb.XGBClassifier(random_state = 42)

# Comprobamos el split

print(y_test_importance.mean())
print(y_train_importance.mean())
print(df_importance['Diagnosis'].mean())
# Out:
# 0.927710843373494
# 0.9163526752072344
# 0.918625678119349

# %%
# Hacemos el RandomizedSearchCV

xgb_rs_importance = RandomizedSearchCV(estimator=xgb_cls_importance,param_distributions=rs_param_grid, 
                                cv=3, n_iter=500, random_state=42)

# Entrenamos nuestro modelo

xgb_rs_importance.fit(X_train_importance, y_train_importance)

xgb_rs_importance.best_params_
# Out:
# {'subsample': 0.5,
#  'n_estimators': 10,
#  'max_depth': 4,
#  'learning_rate': 0.01,
#  'alpha': 0.01}

# %%
# Entrenamos el modelo con los parametros ajustados

xgb_cls_importance.set_params(n_stimators=10, max_depth= 4, subsample=0.5, learning_rate=0.01, alpha= 0.01)
xgb_cls_importance.fit(X_train_importance, y_train_importance)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:160: UserWarning: [14:11:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_stimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(alpha=0.01, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
# ...

# %%
# Resultados sobre el train

print(confusion_matrix(y_train_importance, xgb_cls_importance.predict(X_train_importance)))
print(accuracy_score(y_train_importance, xgb_cls_importance.predict(X_train_importance)))
print(recall_score(y_train_importance, xgb_cls_importance.predict(X_train_importance)))
print(precision_score(y_train_importance, xgb_cls_importance.predict(X_train_importance)))
# Out:
# [[   9  102]
#  [   0 1216]]
# 0.9231348907309721
# 1.0
# 0.9226100151745068

# %%
# Resultados sobre el train

print(confusion_matrix(y_test_importance, xgb_cls_importance.predict(X_test_importance)))
print(accuracy_score(y_test_importance, xgb_cls_importance.predict(X_test_importance)))
print(recall_score(y_test_importance, xgb_cls_importance.predict(X_test_importance)))
print(precision_score(y_test_importance, xgb_cls_importance.predict(X_test_importance)))
# Out:
# [[  1  23]
#  [  0 308]]
# 0.9307228915662651
# 1.0
# 0.9305135951661632
